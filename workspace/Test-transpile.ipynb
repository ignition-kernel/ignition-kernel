# %%
cd pylib/lib3to6/src/
# Out:
# c:\Workspace\Jupyter\ignition_kernel\pylib\lib3to6\src

# %%
import lib3to6

# %%
lib3to6.fix({'traitlets': '../../traitlets/traitlets'})
# Out:
# ---------------------------------------------------------------------------
# CheckError                                Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 lib3to6.fix({'traitlets': '../../traitlets/traitlets'})
#
# File c:\Workspace\Jupyter\ignition_kernel\pylib\lib3to6\src\lib3to6\packaging.py:184, in fix(package_dir, target_version, install_requires, default_mode)
#     178 build_package_dir = init_build_package_dir(package_dir)
#     179 build_cfg         = eval_build_config(
#     180     target_version=target_version,
#     181     install_requires=install_requires,
#     182     default_mode=default_mode,
#     183 )
# --> 184 build_packages(build_cfg, build_package_dir)
#     185 return build_package_dir
#
# File c:\Workspace\Jupyter\ignition_kernel\pylib\lib3to6\src\lib3to6\packaging.py:163, in build_packages(cfg, build_package_dir)
#     160 CACHE_DIR.mkdir(exist_ok=True)
# ...
